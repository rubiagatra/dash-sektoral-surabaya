# %%
import pandas as pd

# %%
df_geo = pd.read_csv("../data/Bab 1_Geografis_v2.0_2016.csv")
df = pd.read_csv("../data/hujansurabaya.csv")

# %%
df.head()
# Out:
#        Bulan  Hari Hujan (Perak)  Curah Hujan (Perak)  Hari Hujan (Juanda)  \
# 0    Januari                  14                284.1                   22
# 1  Februari                   27                409.3                   28
# 2      Maret                  16                163.1                   26
# 3     April                   15                129.6                   21
# 4        Mei                  21                358.8                   21
#
#    Curah Hujan (Juanda)
# 0                   167
# 1                   590
# 2                   252
# 3                   235
# 4                   393

# %%
df_geo.head()
# Out:
#       Bulan  Maksimal Kelembaban (%) di Juanda  \
# 0   Januari                                 97
# 1  Pebruari                                 98
# 2     Maret                                 97
# 3     April                                 97
# 4       Mei                                 95
#
#    Minimal Kelembaban (%) di Juanda  Maksimal Tekanan Udara (Mbs) di Juanda  \
# 0                                52                                  1013.9
# 1                                58                                  1013.2
# 2                                58                                  1013.7
# 3                                58                                  1012.5
# 4                                57                                  1012.2
#
#    Minimal Tekanan Udara (Mbs) di Juanda  \
# 0                                 1008.8
# 1                                 1008.7
# 2                                 1008.8
# 3                                 1009.7
# 4                                 1008.3
#
#    Maksimal Temperatur (Celcius)  di Juanda  \
# 0                                      35.4
# 1                                      34.0
# 2                                      34.3
# 3                                      34.4
# 4                                      33.7
#
#    Minimal Temperatur (Celcius)  di Juanda  \
# 0                                     23.5
# 1                                     24.1
# 2                                     20.4
# 3                                     24.2
# 4                                     23.6
#
#    Rata-rata Kelembaban (%) di Tanjung Perak  \
# 0                                         76
# 1                                         81
# 2                                         77
# 3                                         80
# 4                                         78
#
#    Rata-rata Tekanan Udara (Mbs) di Tanjung Perak  \
# 0                                          1010.9
# 1                                          1010.5
# 2                                          1010.7
# 3                                          1010.3
# 4                                          1009.7
#
#    Rata-rata Temperatur (Celcius) di Tanjung Perak
# 0                                             29.7
# 1                                             29.1
# 2                                             30.0
# 3                                             29.6
# 4                                             30.1

# %%
df.join(df_geo.iloc[:,1:]).to_csv("../data/Bab 1_Geografis_v2.0_2016.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 15 columns):
# Bulan                                                                                 13 non-null object
# Peraturan Daerah [Produk Hukum]                                                       13 non-null int64
# Peraturan Walikota [Produk Hukum]                                                     13 non-null int64
# Keputusan Walikota [Produk Hukum]                                                     13 non-null int64
# Instruksi Walikota [Produk Hukum]                                                     13 non-null int64
# Balik Nama/Waktu Penyelesaian (12 hari kerja) [Berkas IPT yang Diproses]              13 non-null float64
# Rekom Pengalihan/Waktu Penyelesaian (10 jam hari kerja) [Berkas IPT yang Diproses]    13 non-null float64
# Rekom IMB/ Waktu Penyelesaian (8 hari kerja) [Berkas IPT yang Diproses]               13 non-null int64
# Perpanjangan/Waktu Penyelesaian (10 hari kerja) [Berkas IPT yang Diproses]            13 non-null float64
# Pemutihan/Waktu Penyelesaian (10 hari kerja) [Berkas IPT yang Diproses]               13 non-null int64
# Jumlah Kecelakaan                                                                     13 non-null float64
# Korban Meninggal                                                                      13 non-null int64
# Korban Luka Berat                                                                     13 non-null int64
# Korban Luka Ringan                                                                    13 non-null float64
# Kerugian beruapa Harta (000 Rp)                                                       13 non-null object
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.6+ KB

# %%
df.columns
# Out:
# Index(['Bulan', 'Peraturan Daerah [Produk Hukum]',
#        'Peraturan Walikota [Produk Hukum]',
#        'Keputusan Walikota [Produk Hukum]',
#        'Instruksi Walikota [Produk Hukum]',
#        'Balik Nama/Waktu Penyelesaian (12 hari kerja) [Berkas IPT yang Diproses]',
#        'Rekom Pengalihan/Waktu Penyelesaian (10 jam hari kerja) [Berkas IPT yang Diproses]',
#        'Rekom IMB/ Waktu Penyelesaian (8 hari kerja) [Berkas IPT yang Diproses]',
#        'Perpanjangan/Waktu Penyelesaian (10 hari kerja) [Berkas IPT yang Diproses]',
#        'Pemutihan/Waktu Penyelesaian (10 hari kerja) [Berkas IPT yang Diproses]',
#        'Jumlah Kecelakaan', 'Korban Meninggal', 'Korban Luka Berat',
#        'Korban Luka Ringan', 'Kerugian beruapa Harta (000 Rp)'],
#       dtype='object')
